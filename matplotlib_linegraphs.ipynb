# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
s_orbitals = pd.read_csv("s_orbitals_1D.csv")

# %%
s_orbitals.head()
# Out:
#           r        1s        2s        3s
# 0  0.000000  0.564190  0.199471  0.108578
# 1  0.517241  0.336349  0.114183  0.061683
# 2  1.034483  0.200519  0.057408  0.029966
# 3  1.551724  0.119542  0.020580  0.009313
# 4  2.068966  0.071266 -0.002445 -0.003390

# %%
# %matplotlib notebook

# %%
plt.figure()
plt.plot(s_orbitals["r"], s_orbitals["1s"])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(s_orbitals["r"], s_orbitals["1s"])
plt.plot(s_orbitals["r"], s_orbitals["2s"])
plt.plot(s_orbitals["r"], s_orbitals["3s"])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
ax.plot(s_orbitals["r"], s_orbitals["1s"])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
ax.plot("r", "1s", data = s_orbitals)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig2, ax2 = plt.subplots()
ax2.plot("r", "1s", data = s_orbitals)
ax2.plot("r", "2s", data = s_orbitals)
ax2.plot("r", "3s", data = s_orbitals)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax.scatter("r", "1s", data = s_orbitals) # Note: this edits Figure 1 above

# %%
fig, ax = plt.subplots()

ax.plot("r", "1s", data=s_orbitals, color="#2565E8")
ax.plot("r", "2s", data=s_orbitals, color="#ed1c24")
ax.plot("r", "3s", data=s_orbitals, color="#393536")

ax.set_ylabel(r"$\Psi$")
ax.set_xlabel("r")
ax.set_xlim(0, 14)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0.0, 14.0)

# %%
fig.savefig('s_orbitals.png', dpi = 300, transparent = True)
fig.savefig('s_orbitals_high_quality.svg')

# %% [markdown]
# # Subplots: multiple graphs on the same figure

# %%
fig, ax = plt.subplots(1, 3)
fig.tight_layout() # This sometimes breaks formatting - check

ax[0].plot("r","1s", data=s_orbitals, linewidth = 2)
ax[1].plot("r","2s", data=s_orbitals, linewidth = 2)
ax[2].plot("r","3s", data=s_orbitals, linewidth = 2)

for axis in ax:
    axis.set_xlabel("r")
    axis.set_ylabel(r"$\psi$")
    axis.legend()
    axis.set_xlim(0, 14)
    axis.set_ylim(-0.05, 0.5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Modifying matplotlib defaults

# %%
import matplotlib as mpl

# %%
# mpl.rcParams

# To view all possible parameters in a dictionary

# %%
mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['font.size'] = 14
mpl.rcParams['legend.fontsize'] = 'large'
